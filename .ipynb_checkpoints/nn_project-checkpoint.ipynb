# %%
import cv2
import mediapipe as mp
import numpy as np
import matplotlib.pyplot as plt

# %%
mp_hands = mp.solutions.hands
mp_draw = mp.solutions.drawing_utils

# %% [markdown]
# # Capture & Draw Landmarks

# %%
def extract_keypoints(results):
    if not results.multi_hand_landmarks:
        return np.zeros(21*3)

    hand_landmarks = results.multi_hand_landmarks[0]

    keypoints = []
    for lm in hand_landmarks.landmark:
        keypoints.append(lm.x)
        keypoints.append(lm.y)
        keypoints.append(lm.z)

    return np.array(keypoints)

# %%
cap = cv2.VideoCapture(0)

with mp_hands.Hands(
    max_num_hands=1,
    model_complexity=1,
    min_detection_confidence=0.7,
    min_tracking_confidence=0.7
) as hands:

    while True:
        ret, frame = cap.read()
        if not ret:
            break
    
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
        results = hands.process(rgb_frame)
    
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                mp_draw.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)
        
        cv2.imshow("Hand Tracking", frame)
    
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Save Landmarks To Create The Dataset

# %%
import os
os.makedirs('dataset/true', exist_ok=True)
os.makedirs('dataset/false', exist_ok=True)

# %%
cap = cv2.VideoCapture(0)

sample_id_true = 253
sample_id_false = 0

with mp_hands.Hands(
    max_num_hands=1,
    model_complexity=1,
    min_detection_confidence=0.7,
    min_tracking_confidence=0.7
) as hands:

    while True:
        ret, frame = cap.read()
        if not ret:
            break
    
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = hands.process(rgb_frame)
    
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                mp_draw.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

        keypoints = extract_keypoints(results)

        key = cv2.waitKey(1) & 0xFF
        if  key == ord('t'):
            np.save(f"dataset/true/{sample_id_true}.npy", keypoints)
            print(f"saved TRUE sample #{sample_id_true}")
            sample_id_true += 1

        if key == ord('f'):
            np.save(f"dataset/false/{sample_id_false}.npy", keypoints)
            print(f"saved FALSE sample #{sample_id_false}")
            sample_id_false += 1
    
        if key == ord('q'):
            break

        cv2.imshow("Hand Tracking", frame)

cap.release()
cv2.destroyAllWindows()
# Out:
# saved TRUE sample #253
# saved TRUE sample #254
# saved TRUE sample #255
# saved TRUE sample #256
# saved TRUE sample #257
# saved TRUE sample #258
# saved TRUE sample #259
# saved TRUE sample #260
# saved TRUE sample #261
# saved TRUE sample #262
# saved TRUE sample #263
# saved TRUE sample #264
# saved TRUE sample #265
# saved TRUE sample #266
# saved TRUE sample #267
# saved TRUE sample #268
# saved TRUE sample #269
# saved TRUE sample #270
# saved TRUE sample #271
# saved TRUE sample #272
# saved TRUE sample #273
# saved TRUE sample #274
# saved TRUE sample #275
# saved TRUE sample #276
# saved TRUE sample #277
# saved TRUE sample #278
# saved TRUE sample #279
# saved TRUE sample #280
# saved TRUE sample #281
# saved TRUE sample #282
# saved TRUE sample #283
# saved TRUE sample #284
# saved TRUE sample #285
# saved TRUE sample #286
# saved TRUE sample #287
# saved TRUE sample #288
# saved TRUE sample #289
# saved TRUE sample #290
# saved TRUE sample #291
# saved TRUE sample #292
# saved TRUE sample #293
# saved TRUE sample #294
# saved TRUE sample #295
# saved TRUE sample #296
# saved TRUE sample #297
# saved TRUE sample #298
# saved TRUE sample #299
# saved TRUE sample #300
# saved TRUE sample #301
# saved TRUE sample #302
# saved TRUE sample #303
# saved TRUE sample #304
# saved TRUE sample #305
# saved TRUE sample #306
# saved TRUE sample #307
# saved TRUE sample #308
# saved TRUE sample #309
# saved TRUE sample #310
# saved TRUE sample #311
# saved TRUE sample #312
# saved TRUE sample #313
# saved TRUE sample #314
# saved TRUE sample #315
# saved TRUE sample #316
# saved TRUE sample #317
# saved TRUE sample #318
# saved TRUE sample #319
# saved TRUE sample #320
# saved TRUE sample #321
# saved TRUE sample #322
# saved TRUE sample #323
# saved TRUE sample #324
# saved TRUE sample #325
# saved TRUE sample #326
# saved TRUE sample #327
# saved TRUE sample #328
# saved TRUE sample #329
# saved TRUE sample #330
# saved TRUE sample #331
# saved TRUE sample #332
# saved TRUE sample #333
# saved TRUE sample #334
# saved TRUE sample #335
# saved TRUE sample #336
# saved TRUE sample #337
# saved TRUE sample #338
# saved TRUE sample #339
# saved TRUE sample #340
# saved TRUE sample #341
# saved TRUE sample #342
# saved TRUE sample #343
# saved TRUE sample #344
# saved TRUE sample #345
# saved TRUE sample #346
# saved TRUE sample #347
# saved TRUE sample #348
# saved TRUE sample #349
# saved TRUE sample #350
# saved TRUE sample #351
# saved TRUE sample #352
# saved TRUE sample #353
# saved TRUE sample #354
# saved TRUE sample #355
# saved TRUE sample #356
# saved TRUE sample #357
# saved TRUE sample #358
# saved TRUE sample #359
# saved TRUE sample #360
# saved TRUE sample #361
# saved TRUE sample #362
# saved TRUE sample #363
# saved TRUE sample #364
# saved TRUE sample #365
# saved TRUE sample #366
# saved TRUE sample #367
# saved TRUE sample #368
# saved TRUE sample #369
# saved TRUE sample #370
# saved TRUE sample #371
# saved TRUE sample #372
# saved TRUE sample #373
# saved TRUE sample #374
# saved TRUE sample #375
# saved TRUE sample #376
# saved TRUE sample #377
# saved TRUE sample #378
# saved TRUE sample #379
# saved TRUE sample #380
# saved TRUE sample #381
# saved TRUE sample #382
# saved TRUE sample #383
# saved TRUE sample #384
# saved TRUE sample #385
# saved TRUE sample #386
# saved TRUE sample #387
# saved TRUE sample #388
# saved TRUE sample #389
# saved TRUE sample #390
# saved TRUE sample #391
# saved TRUE sample #392
# saved TRUE sample #393
# saved TRUE sample #394
# saved TRUE sample #395
# saved TRUE sample #396
# saved TRUE sample #397
# saved TRUE sample #398
# saved TRUE sample #399
# saved TRUE sample #400
# saved TRUE sample #401
# saved TRUE sample #402
# saved TRUE sample #403
# saved TRUE sample #404
# saved TRUE sample #405
# saved TRUE sample #406
# saved TRUE sample #407
# saved TRUE sample #408
# saved TRUE sample #409
# saved TRUE sample #410
# saved TRUE sample #411
# saved TRUE sample #412
# saved TRUE sample #413
# saved TRUE sample #414
# saved TRUE sample #415
# saved TRUE sample #416
# saved TRUE sample #417
# saved TRUE sample #418
# saved TRUE sample #419
# saved TRUE sample #420
# saved TRUE sample #421
# saved TRUE sample #422
# saved TRUE sample #423
# saved TRUE sample #424

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Load Arrays To Create The Dataset

# %%
from sklearn.model_selection import train_test_split
from collections import Counter

# %%
def load_npy_folder(folder):
    files = sorted([os.path.join(folder, f) for f in os.listdir(folder) if f.endswith('.npy')])
    data = []
    for f in files:
        try:
            arr = np.load(f)
            data.append(arr)
        except Exception as e:
            print(f"Couldn't load {f}: {e}")
    return data

# %%
TRUE_DIR = "dataset/true"
FALSE_DIR = "dataset/false"

true_samples = load_npy_folder(TRUE_DIR)
false_samples = load_npy_folder(FALSE_DIR)

# %%
X_true = np.vstack(true_samples) if len(true_samples) else np.empty((0, 63))
X_false = np.vstack(false_samples) if len(false_samples) else np.empty((0, 63))
y_true = np.ones(len(X_true), dtype=np.int32)
y_false = np.zeros(len(X_false), dtype=np.int32)

# %%
X = np.vstack([X_true, X_false])
y = np.concatenate([y_true, y_false])

# %%
Counter(y)
# Out:
# Counter({np.int32(1): 425, np.int32(0): 401})

# %%
TEST_SIZE = 0.2
RANDOM_STATE = 42

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE, shuffle=True, stratify=y
)

# %%
print("Train shape:", X_train.shape, "Test shape:", X_test.shape)
print("Train class counts:", Counter(y_train))
print("Test class counts:", Counter(y_test))
# Out:
# Train shape: (660, 63) Test shape: (166, 63)
# Train class counts: Counter({np.int32(1): 340, np.int32(0): 320})
# Test class counts: Counter({np.int32(1): 85, np.int32(0): 81})

# %% [markdown]
# # Train The NN Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import matplotlib.pyplot as plt

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 128)            │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,561 (72.50 KB)
#  Trainable params: 18,561 (72.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train, y_train,
    epochs=60,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6136 - loss: 0.6614 - val_accuracy: 0.6591 - val_loss: 0.6240
# Epoch 2/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6989 - loss: 0.5930 - val_accuracy: 0.6970 - val_loss: 0.5865
# Epoch 3/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7102 - loss: 0.5619 - val_accuracy: 0.6970 - val_loss: 0.5736
# Epoch 4/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7216 - loss: 0.5429 - val_accuracy: 0.7273 - val_loss: 0.5137
# Epoch 5/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7443 - loss: 0.5150 - val_accuracy: 0.7652 - val_loss: 0.4973
# Epoch 6/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7879 - loss: 0.4564 - val_accuracy: 0.8258 - val_loss: 0.4073
# Epoch 7/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8447 - loss: 0.3934 - val_accuracy: 0.9091 - val_loss: 0.3164
# Epoch 8/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8466 - loss: 0.3752 - val_accuracy: 0.8712 - val_loss: 0.2680
# Epoch 9/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8996 - loss: 0.2808 - val_accuracy: 0.9621 - val_loss: 0.1939
# Epoch 10/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9129 - loss: 0.2375 - val_accuracy: 0.8939 - val_loss: 0.2381
# Epoch 11/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9129 - loss: 0.2254 - val_accuracy: 0.9697 - val_loss: 0.1193
# Epoch 12/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9223 - loss: 0.2168 - val_accuracy: 0.9015 - val_loss: 0.2284
# Epoch 13/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9034 - loss: 0.2395 - val_accuracy: 0.9773 - val_loss: 0.0933
# Epoch 14/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9470 - loss: 0.1638 - val_accuracy: 0.9621 - val_loss: 0.1204
# Epoch 15/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9394 - loss: 0.1580 - val_accuracy: 0.9697 - val_loss: 0.0793
# Epoch 16/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9470 - loss: 0.1545 - val_accuracy: 0.9773 - val_loss: 0.0812
# Epoch 17/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9489 - loss: 0.1403 - val_accuracy: 0.9773 - val_loss: 0.0743
# Epoch 18/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9564 - loss: 0.1257 - val_accuracy: 0.9773 - val_loss: 0.0589
# Epoch 19/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9640 - loss: 0.0988 - val_accuracy: 0.9773 - val_loss: 0.0659
# Epoch 20/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9451 - loss: 0.1309 - val_accuracy: 0.9773 - val_loss: 0.0659
# Epoch 21/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9527 - loss: 0.1113 - val_accuracy: 0.9848 - val_loss: 0.0510
# Epoch 22/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9602 - loss: 0.1179 - val_accuracy: 0.9924 - val_loss: 0.0472
# Epoch 23/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1022 - val_accuracy: 0.9924 - val_loss: 0.0479
# Epoch 24/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9640 - loss: 0.0932 - val_accuracy: 0.9848 - val_loss: 0.0570
# Epoch 25/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9602 - loss: 0.0972 - val_accuracy: 0.9924 - val_loss: 0.0293
# Epoch 26/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1102 - val_accuracy: 0.9848 - val_loss: 0.0356
# Epoch 27/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9564 - loss: 0.1056 - val_accuracy: 0.9697 - val_loss: 0.0839
# Epoch 28/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9716 - loss: 0.0861 - val_accuracy: 0.9848 - val_loss: 0.0526
# Epoch 29/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9640 - loss: 0.0851 - val_accuracy: 0.9924 - val_loss: 0.0327
# Epoch 30/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9659 - loss: 0.0848 - val_accuracy: 0.9848 - val_loss: 0.0521
# Epoch 31/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9678 - loss: 0.0814 - val_accuracy: 0.9773 - val_loss: 0.0710
# Epoch 32/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9735 - loss: 0.0767 - val_accuracy: 0.9848 - val_loss: 0.0356
# Epoch 33/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9735 - loss: 0.0647 - val_accuracy: 1.0000 - val_loss: 0.0163
# Epoch 34/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9678 - loss: 0.0798 - val_accuracy: 0.9773 - val_loss: 0.0523
# Epoch 35/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9602 - loss: 0.0884 - val_accuracy: 1.0000 - val_loss: 0.0227
# Epoch 36/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9678 - loss: 0.0707 - val_accuracy: 1.0000 - val_loss: 0.0214
# Epoch 37/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9735 - loss: 0.0695 - val_accuracy: 0.9848 - val_loss: 0.0273
# Epoch 38/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9716 - loss: 0.0832 - val_accuracy: 0.9924 - val_loss: 0.0206
# Epoch 39/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9716 - loss: 0.0675 - val_accuracy: 1.0000 - val_loss: 0.0149
# Epoch 40/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9773 - loss: 0.0656 - val_accuracy: 1.0000 - val_loss: 0.0143
# Epoch 41/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9773 - loss: 0.0610 - val_accuracy: 1.0000 - val_loss: 0.0226
# Epoch 42/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9773 - loss: 0.0541 - val_accuracy: 0.9924 - val_loss: 0.0156
# Epoch 43/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9773 - loss: 0.0428 - val_accuracy: 1.0000 - val_loss: 0.0159
# Epoch 44/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9848 - loss: 0.0481 - val_accuracy: 1.0000 - val_loss: 0.0138
# Epoch 45/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9697 - loss: 0.0783 - val_accuracy: 0.9773 - val_loss: 0.0451
# Epoch 46/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9564 - loss: 0.1066 - val_accuracy: 0.9848 - val_loss: 0.0472
# Epoch 47/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9678 - loss: 0.0826 - val_accuracy: 0.9924 - val_loss: 0.0275
# Epoch 48/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9735 - loss: 0.0665 - val_accuracy: 0.9848 - val_loss: 0.0245
# Epoch 49/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9773 - loss: 0.0598 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 50/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9811 - loss: 0.0521 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 51/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9792 - loss: 0.0536 - val_accuracy: 1.0000 - val_loss: 0.0136
# Epoch 52/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9754 - loss: 0.0531 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 53/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9773 - loss: 0.0406 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 54/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9830 - loss: 0.0475 - val_accuracy: 0.9848 - val_loss: 0.0321
# Epoch 55/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9716 - loss: 0.0676 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 56/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9773 - loss: 0.0534 - val_accuracy: 1.0000 - val_loss: 0.0089
# Epoch 57/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9773 - loss: 0.0429 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 58/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9811 - loss: 0.0400 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 59/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9659 - loss: 0.0656 - val_accuracy: 0.9924 - val_loss: 0.0215
# Epoch 60/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9811 - loss: 0.0517 - val_accuracy: 1.0000 - val_loss: 0.0064

# %%
plt.figure(figsize=(12,5))

# Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label="Train Loss")
plt.plot(history.history['val_loss'], label="Val Loss")
plt.title("Loss")
plt.legend()

# Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label="Train Acc")
plt.plot(history.history['val_accuracy'], label="Val Acc")
plt.title("Accuracy")
plt.legend()

plt.show()

# %% [markdown]
# # Evaluate The Model

# %%
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy :", acc)
print("Precision:", prec)
print("Recall   :", rec)
print("F1 Score :", f1)
# Out:
# Accuracy : 0.9759036144578314
# Precision: 0.9550561797752809
# Recall   : 1.0
# F1 Score : 0.9770114942528736

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %% [markdown]
# # Save Weights

# %%
model.save('nn_project.h5')

# %% [markdown]
# # Test in Real Time

# %%
from tensorflow.keras.models import load_model

model = load_model('nn_project.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
y_probs = model.predict(X_test)
y_probs.shape
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# (166, 1)

# %%
from sklearn.metrics import roc_curve, roc_auc_score

fpr, tpr, thresholds = roc_curve(y_test, y_probs)
roc_auc = roc_auc_score(y_test, y_probs)

print("ROC-AUC:", roc_auc)
# Out:
# ROC-AUC: 0.9996368917937546

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.3f})")
plt.plot([0, 1], [0, 1], linestyle="--", label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.grid(True)
plt.show()

# %%
cap = cv2.VideoCapture(0)

with mp_hands.Hands(
    max_num_hands=1,
    model_complexity=1,
    min_detection_confidence=0.7,
    min_tracking_confidence=0.7
) as hands:

    while True:
        ret, frame = cap.read()
        # if not ret:
        #     break
    
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
        results = hands.process(rgb_frame)

        keypoints = extract_keypoints(results)

        if np.any(keypoints):
            pred = model.predict(np.array([keypoints]), verbose=0)[0][0]
            prediction = "True" if pred > 0.75 else "False"
            conf = float(pred)
        else:
            prediction = "No Hand"
            conf = 0.0
        
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                mp_draw.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

        cv2.putText(frame, f"Prediction: {prediction} ({conf:.2f})",
                (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)
        
        cv2.imshow("Real-Time Test", frame)
    
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# D:\anaconda3\envs\lstm_env\lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
cap.release()
cv2.destroyAllWindows()

# %%
np.array(extract_keypoints(results)).shape
# Out:
# (63,)

# %%
# X_test[0].shape

# %%
model.predict(np.array([extract_keypoints(results)]))[0][0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# np.float32(0.0054462776)

# %% [markdown]
# # Use Pyautogui To Move The Cursor

# %%
import pyautogui
from filterpy.kalman import KalmanFilter

# %%
pyautogui.FAILSAFE = False
pyautogui.MINIMUM_DURATION = 0
pyautogui.MINIMUM_SLEEP = 0
pyautogui.PAUSE = 0

# %%
cap = cv2.VideoCapture(0)
smooth_x, smooth_y = 0, 0
alpha = 0.25

with mp_hands.Hands(
    max_num_hands=1,
    model_complexity=0,
    min_detection_confidence=0.6,
    min_tracking_confidence=0.6
) as hands:

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        small_frame = cv2.resize(frame, (320, 240))
        rgb = cv2.cvtColor(small_frame, cv2.COLOR_BGR2RGB)

        results = hands.process(rgb)

        if results.multi_hand_landmarks:
            hand = results.multi_hand_landmarks[0]

            keypoints = extract_keypoints(results)
            keypoints = np.array(keypoints).reshape(1, -1)

            pred = model.predict(keypoints, verbose=0)[0][0]

            if pred > 0.75:
                index_tip = hand.landmark[8]

                screen_w, screen_h = pyautogui.size()
                target_x = int((1 - index_tip.x) * screen_w)
                target_y = int(index_tip.y * screen_h)

                smooth_x = int(alpha * target_x + (1 - alpha) * smooth_x)
                smooth_y = int(alpha * target_y + (1 - alpha) * smooth_y)

                pyautogui.moveTo(smooth_x, smooth_y, duration=0)

        cv2.imshow("Cursor Control", frame)
    
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# D:\anaconda3\envs\lstm_env\lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Add Left & Right Click

# %%
def fingertip_distance(landmark_1, landmark_2):
    return np.sqrt((landmark_1.x - landmark_2.x)**2 + (landmark_1.y - landmark_2.y)**2)

# %%
cap = cv2.VideoCapture(0)

smooth_x, smooth_y = 0, 0
alpha = 0.25

left_clicked = False
right_clicked = False
click_threshold = 0.04

with mp_hands.Hands(
    max_num_hands=1,
    model_complexity=0,
    min_detection_confidence=0.6,
    min_tracking_confidence=0.6
) as hands:

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        small_frame = cv2.resize(frame, (320, 240))
        rgb = cv2.cvtColor(small_frame, cv2.COLOR_BGR2RGB)

        results = hands.process(rgb)

        if results.multi_hand_landmarks:
            hand = results.multi_hand_landmarks[0]

            keypoints = extract_keypoints(results)
            keypoints = np.array(keypoints).reshape(1, -1)

            pred = model.predict(keypoints, verbose=0)[0][0]

            if pred > 0.75:
                index_tip = hand.landmark[8]

                screen_w, screen_h = pyautogui.size()
                target_x = int((1 - index_tip.x) * screen_w)
                target_y = int(index_tip.y * screen_h)

                smooth_x = int(alpha * target_x + (1 - alpha) * smooth_x)
                smooth_y = int(alpha * target_y + (1 - alpha) * smooth_y)

                pyautogui.moveTo(smooth_x, smooth_y, duration=0)


            # left click
            distance_index_thumb = fingertip_distance(hand.landmark[4], hand.landmark[8])
            if distance_index_thumb < click_threshold and not left_clicked:
                left_clicked = True
                pyautogui.click(button="left")
                print("Left Clicked")

            if distance_index_thumb > click_threshold:
                left_clicked = False

            # right click
            distance_pinky_thumb = fingertip_distance(hand.landmark[4], hand.landmark[20])
            if distance_pinky_thumb < click_threshold and not right_clicked:
                right_clicked = True
                pyautogui.click(button="right")
                print("Right Clicked")

            if distance_pinky_thumb > click_threshold:
                right_clicked = False
        
        cv2.imshow("Cursor Control", frame)
    
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# D:\anaconda3\envs\lstm_env\lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # UI Inhancements

# %%
cap = cv2.VideoCapture(0)

smooth_x, smooth_y = 0, 0
alpha = 0.25

left_clicked = False
right_clicked = False
click_threshold = 0.04

FRAME_MARGIN_X = 0.10
FRAME_MARGIN_TOP = 0.05
FRAME_MARGIN_BOTTOM = 0.35

with mp_hands.Hands(
    max_num_hands=1,
    model_complexity=0,
    min_detection_confidence=0.6,
    min_tracking_confidence=0.6
) as hands:

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        small_frame = cv2.resize(frame, (320, 240))
        rgb = cv2.cvtColor(small_frame, cv2.COLOR_BGR2RGB)

        results = hands.process(rgb)

        h, w = frame.shape[:2]
        
        x1 = int(FRAME_MARGIN_X * w)
        y1 = int(FRAME_MARGIN_TOP * h)
        x2 = int((1 - FRAME_MARGIN_X) * w)
        y2 = int((1 - FRAME_MARGIN_BOTTOM) * h)
        
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0) if pred > 0.75 else (0,0,255), 2)

        cv2.putText(frame, f"Move: {'YES' if pred > 0.75 else 'NO'}",
                    (x1, y2 + 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0) if pred > 0.75 else (0,0,255), 2)
        
        cv2.putText(frame, f"Confidence: {pred:.2f}",
                    (x1, y2 + 60), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0) if pred > 0.75 else (0,0,255), 2)
        
        if results.multi_hand_landmarks:
            hand = results.multi_hand_landmarks[0]

            keypoints = extract_keypoints(results)
            keypoints = np.array(keypoints).reshape(1, -1)

            pred = model.predict(keypoints, verbose=0)[0][0]

            if pred > 0.75:
                index_tip = hand.landmark[8]

                fx, fy = index_tip.x, index_tip.y
                
                min_x = FRAME_MARGIN_X
                max_x = 1.0 - FRAME_MARGIN_X
                min_y = FRAME_MARGIN_TOP
                max_y = 1.0 - FRAME_MARGIN_BOTTOM

                fx = np.clip(fx, min_x, max_x)
                fy = np.clip(fy, min_y, max_y)

                nx = (fx - min_x) / (max_x - min_x)
                ny = (fy - min_y) / (max_y - min_y)
                
                screen_w, screen_h = pyautogui.size()
                target_x = int((1-nx) * screen_w)
                target_y = int(ny * screen_h)

                smooth_x = int(alpha * target_x + (1 - alpha) * smooth_x)
                smooth_y = int(alpha * target_y + (1 - alpha) * smooth_y)

                pyautogui.moveTo(smooth_x, smooth_y, duration=0)

                cv2.circle(frame, (int(index_tip.x * frame.shape[1]),
                   int(index_tip.y * frame.shape[0])),
                   8, (0,255,0), -1)


            # left click
            distance_index_thumb = fingertip_distance(hand.landmark[4], hand.landmark[8])
            if distance_index_thumb < click_threshold and not left_clicked:
                left_clicked = True
                pyautogui.click(button="left")
                print("Left Clicked")

            if distance_index_thumb > click_threshold:
                left_clicked = False

            # right click
            distance_pinky_thumb = fingertip_distance(hand.landmark[4], hand.landmark[20])
            if distance_pinky_thumb < click_threshold and not right_clicked:
                right_clicked = True
                pyautogui.click(button="right")
                print("Right Clicked")

            if distance_pinky_thumb > click_threshold:
                right_clicked = False
        
        cv2.imshow("Cursor Control", frame)
    
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Left Clicked
# Left Clicked
# Right Clicked
# Left Clicked
# Left Clicked
# Left Clicked
# Left Clicked
# Left Clicked

# %%
cap.release()
cv2.destroyAllWindows()
